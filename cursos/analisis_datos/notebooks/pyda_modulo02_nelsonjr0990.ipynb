# %% [markdown]
# # Módulo 2 – Limpieza y Transformación de Datos
#
# En esta sesión aprenderás a preparar tus datos antes de un análisis profundo. Trabajaremos con los datasets **`salarios.csv`** y **`paises.csv`** ubicados en `data/raw/`.

# %% [markdown]
# ##  Objetivos de la sesión
# - Detectar y manejar **valores nulos** y **duplicados**.
# - Limpiar columnas monetarias y convertir tipos de datos.
# - **Unir** (merge) datasets por claves comunes.
# - Crear **nuevas columnas** útiles para el análisis.
# - Exportar los datos limpios a `data/processed/`.

# %% [markdown]
# ## Recuerden la Estructura de un proyecto
#
# Una estructura recomendada puede ser:
# ```
# project-name/
# ├── assest/           # Imagenes, graficos (generalmente no se sube a github)
# ├── data/             # Datos crudos y procesados
#     ├──── raw/
#     ├──── processed/   --> Crear esta carpeta si no la tienen
# ├── notebooks/        # Notebooks del proyecto
# ├── utils/            # Funciones auxiliares
# ├── docs/             # Documentación
# ├── README.md         # Descripción general
# ├── environment.yml   # Dependencias usando conda
# └── requirements.txt  # Dependencias usando pip

# %% [markdown]
# ---
# ## 1 · Importar librerías y cargar datasets
# Comenzamos cargando Pandas y leyendo los archivos CSV desde la carpeta `data/raw/`.

# %% [markdown]
# ### 📦 Librerías que usaremos
# Importamos módulos clave para:
#
# * **pandas / numpy** → manipulación numérica y tabular
# * **matplotlib / seaborn** → gráficos rápidos (los usaremos más adelante)
# * **pathlib** → manejar rutas de forma independiente del sistema operativo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %% [markdown]
# ### 🔍 Ubicar el archivo de salarios
# Utilizamos la constante `DATA_RAW_DIR` (definida en `utils.paths`) para construir
# la ruta absoluta a **salarios.csv**.
# Esto evita escribir paths “hard-codeados” y hace el notebook portable.

# %%
#Importar la carpeta de datos raw desde paths
from cursos.analisis_datos.utils.paths import DATA_RAW_DIR

#definir un path o ruta con Path
path_salarios = DATA_RAW_DIR / "salarios.csv"
path_salarios = str(path_salarios)

print(f"Ruta del archivo salarios: {path_salarios}")
print(f"existe archivo salarios: {Path(path_salarios).exists()}")
# Out:
# Ruta del archivo salarios: C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\raw\salarios.csv
# existe archivo salarios: True

# %% [markdown]
# ### 📥 Carga del dataset de salarios
# Leemos el archivo con `pd.read_csv()`.
# * `sep=','` porque es un CSV estándar.
# * `encoding='utf-8'` asegura que caracteres latinos/acentos se lean bien.

# %%
df_salarios = pd.read_csv(filepath_or_buffer=path_salarios, sep=',', encoding='utf-8')

# %%
df_salarios.head(7)
# Out:
#      nombre apellido  edad        pais educacion_universitaria  \
# 0      José    López    36       Chile                      Sí
# 1  Fernanda   Vargas    39       Chile                      Sí
# 2  Fernanda  Ramírez    30    Colombia                      No
# 3      José    Gómez    35       Chile                      Sí
# 4       Ana    Pérez    32      Panamá                      No
# 5    Andrea   Torres    45  Costa Rica                      No
# 6    Andrea   Vargas    58       Chile                      No
#
#   nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 0        Mercado Libre           Python Developer                   2
# 1               Amazon       AI Software Engineer                   2
# 2             Facebook  Machine Learning Engineer                   2
# 3        Mercado Libre           Python Developer                  12
# 4               Amazon            Project Manager                   2
# 5        Mercado Libre              Data Engineer                   8
# 6        Mercado Libre             Data Scientist                   9
#
#   sueldo_anual bono_anual
# 0       $71841      €4981
# 1      $142115      €1252
# 2       $92278      €5262
# 3       $97130      €3671
# 4       $61413     €10190
# 5       $84987      €5493
# 6       $96936      €4911

# %% [markdown]
# ---
# ## 2 · Explorar la estructura del dataset
# ### 2.1 Información general
# Revisamos tipos de datos, cantidad de filas/columnas y valores nulos.

# %% [markdown]
# ### 🏷️ Inspección rápida del DataFrame
# `df.info()` resume:
# * Columnas y tipos (`object`, `int64`, etc.)
# * Filas no-nulas por columna → detectamos valores faltantes (`pais`, `empresa`)
# * Memoria ocupada

# %%
df_salarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nombre                   325 non-null    object
#  1   apellido                 325 non-null    object
#  2   edad                     325 non-null    int64
#  3   pais                     324 non-null    object
#  4   educacion_universitaria  325 non-null    object
#  5   nombre_de_la_empresa     317 non-null    object
#  6   cargo                    325 non-null    object
#  7   anos_en_la_empresa       325 non-null    int64
#  8   sueldo_anual             325 non-null    object
#  9   bono_anual               325 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 25.5+ KB

# %% [markdown]
# ### 2.2 Estadísticas descriptivas rápidas

# %% [markdown]
# ### 📊 Estadísticas descriptivas
# `df.describe()` genera medidas (count, mean, std…) solo para columnas
# numéricas. Aquí vemos *edad* y *años en la empresa*.
# Esto ayuda a detectar outliers y entender la dispersión.

# %%
df_salarios.describe()
# Out:
#              edad  anos_en_la_empresa
# count  325.000000          325.000000
# mean    40.889231            6.353846
# std     11.582769            3.997803
# min     22.000000            0.000000
# 25%     30.000000            3.000000
# 50%     41.000000            6.000000
# 75%     51.000000           10.000000
# max     60.000000           13.000000

# %% [markdown]
# ---
# ## 3 · Limpiar columnas monetarias
# Las columnas `sueldo_anual` y `bono_anual` tienen símbolos de moneda. Eliminamos `$` y `€` y convertimos a `float`.

# %%
df_salarios.head()
# Out:
#      nombre apellido  edad      pais educacion_universitaria  \
# 0      José    López    36     Chile                      Sí
# 1  Fernanda   Vargas    39     Chile                      Sí
# 2  Fernanda  Ramírez    30  Colombia                      No
# 3      José    Gómez    35     Chile                      Sí
# 4       Ana    Pérez    32    Panamá                      No
#
#   nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 0        Mercado Libre           Python Developer                   2
# 1               Amazon       AI Software Engineer                   2
# 2             Facebook  Machine Learning Engineer                   2
# 3        Mercado Libre           Python Developer                  12
# 4               Amazon            Project Manager                   2
#
#   sueldo_anual bono_anual
# 0       $71841      €4981
# 1      $142115      €1252
# 2       $92278      €5262
# 3       $97130      €3671
# 4       $61413     €10190

# %% [markdown]
# Revisar las columnas `sueldo_anual` y `bono_anual` pues tienen los simbolos de moneda

# %% [markdown]
# ### 💲 Columnas monetarias originales
# Previsualizamos `sueldo_anual` y `bono_anual` antes de limpiarlas.
# Observa que contienen símbolos (`$`, `€`)

# %%
# escribe tu codigo aqui
df_salarios[['sueldo_anual', 'bono_anual']]
# Out:
#     sueldo_anual bono_anual
# 0         $71841      €4981
# 1        $142115      €1252
# 2         $92278      €5262
# 3         $97130      €3671
# 4         $61413     €10190
# ..           ...        ...
# 320       $97114      €1684
# 321      $104541      €3128
# 322       $86042      €8746
# 323       $96078     €11419
# 324       $93115      €3426
#
# [325 rows x 2 columns]

# %% [markdown]
# Renombrar las columnas usando `.rename`
#
# ```python
# columns={
#         "sueldo_anual": "sueldo_anual_dolares",
#         "bono_anual": "bono_anual_euros"
#     }
# ```

# %%
# Renombrar las columnas usando `.rename`
df_salarios.rename(columns={"sueldo_anual": "sueldo_anual_dolares","bono_anual": "bono_anual_euros"},inplace=True)

# %%
print(df_salarios.columns.to_list())
# Out:
# ['nombre', 'apellido', 'edad', 'pais', 'educacion_universitaria', 'nombre_de_la_empresa', 'cargo', 'anos_en_la_empresa', 'sueldo_anual_dolares', 'bono_anual_euros']

# %% [markdown]
# Revisar si las columnas cambiaron de nombre con `.columns`

# %%
# Revisar si las columnas cambiaron de nombre con `.columns`
df_salarios.columns
# Out:
# Index(['nombre', 'apellido', 'edad', 'pais', 'educacion_universitaria',
#        'nombre_de_la_empresa', 'cargo', 'anos_en_la_empresa',
#        'sueldo_anual_dolares', 'bono_anual_euros'],
#       dtype='object')

# %% [markdown]
# Reemplazar el simbolo de dólar `$` por  `''` utilizando el método `.replace()`

# %% [markdown]
# ### ✂️ Eliminar símbolo de dólar
# `str.replace('$','')` quita el carácter pero **deja las comas**.
# Aún es tipo `object` (string); falta:
# 1. eliminar comas,
# 2. convertir a `float`.

# %%
# escribe tu codigo aqui
df_salarios.columns.to_list()

df_salarios['sueldo_anual_dolares'] = df_salarios['sueldo_anual_dolares'].str.replace('$', '')

# %% [markdown]
# Cambiar el tipo de dato de sueldo_anual_dolares con `.astype(float)`

# %% [markdown]
# > **Nota:** se produce un `ValueError` porque todavía hay **celdas vacías**
#   (`''`) o valores con comas que impiden la conversión directa a `float`.

# %%
df_salarios['sueldo_anual_dolares'] = df_salarios['sueldo_anual_dolares'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df_salarios['sueldo_anual_dolares'] = df_salarios['sueldo_anual_dolares'].astype(float)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: ''

# %%
import numpy as np
import pandas as pd

# ── 1. LIMPIAR la columna de bonos ───────────────────────────
df_salarios["bono_anual_euros"] = (
    df_salarios["bono_anual_euros"]
        .astype(str)                        # por si hay números ya
        .str.strip()                        # quita espacios laterales
        .str.replace("€", "", regex=False)  # quita símbolo de euro
        .str.replace(",", "", regex=False)  # quita separador de miles
)

# ── 2. CONVERTIR a float, forzando errores a NaN ─────────────
df_salarios["bono_anual_euros"] = pd.to_numeric(
    df_salarios["bono_anual_euros"],
    errors="coerce"        # lo que no se pueda convertir → NaN
)

# ── 3. COMPROBAR ─────────────────────────────────────────────
print(df_salarios["bono_anual_euros"].dtype)              # float64
print("NaNs:", df_salarios["bono_anual_euros"].isna().sum())
print(df_salarios[["bono_anual_euros"]].head())
# Out:
# int64
# NaNs: 0
#    bono_anual_euros
# 0              4981
# 1              1252
# 2              5262
# 3              3671
# 4             10190

# %% [markdown]
# ### Funcionó? o Cuál es el error?

# %% [markdown]
# ##### Tu respuesta aqui

# %% [markdown]
# reemplazar las celdas vacias `''`

# %%
#reemplazar las celdas vacias a np.nan
df_salarios['bono_anual_euros'] = df_salarios['bono_anual_euros'].replace('', np.nan)

# %% [markdown]
# ### 🛠️ Reemplazar strings vacíos por `NaN`
# Usamos `.replace('', np.nan)` para que pandas los reconozca como faltantes
# y permita la conversión numérica en el siguiente paso.

# %%
# .replace('', np.nan)` para que pandas los reconozca como faltantes y permita la conversión numérica en el siguiente paso.
df_salarios['bono_anual_euros'] = df_salarios['bono_anual_euros'].replace('', np.nan)

# %% [markdown]
# Cambiar el tipo de datos con `.astype(float)`

# %% [markdown]
# ### 🔄 Convertir a numérico
# Ahora que no hay símbolos ni strings vacíos, `astype(float)` funciona.
# El resultado es una columna `float64` lista para cálculos.

# %%
# sin simbolos ni strings vacíos float64
df_salarios['bono_anual_euros'] = df_salarios['bono_anual_euros'].astype(float)

# %% [markdown]
# Revisar que valores de `sueldo_anual_dolares` tienen el valor `np.nan`

# %% [markdown]
# ### 📌 Ver cuántos salarios quedaron como `NaN`
# Esto nos indica cuántos registros tendrán que imputarse
# o eliminarse en el siguiente bloque de limpieza.

# %%
# cuantos salarios con nan
print(df_salarios['sueldo_anual_dolares'].isna().sum())
# Out:
# 0

# %% [markdown]
# ### 🔍 Inspeccionar filas con salario faltante
# Listamos las 7 filas donde `sueldo_anual_dolares` es `NaN`.
# Podremos decidir si:
# * imputar con la mediana por cargo/país,
# * o eliminar si los valores son críticos.

# %%
df_salarios[df_salarios['sueldo_anual_dolares'].isna()]
# Out:
# Empty DataFrame
# Columns: [nombre, apellido, edad, pais, educacion_universitaria, nombre_de_la_empresa, cargo, anos_en_la_empresa, sueldo_anual_dolares, bono_anual_euros]
# Index: []

# %% [markdown]
# Ahora el mismo proceso con el símbolo de euros `€`

# %%
df_salarios['bono_anual_euros'] = (df_salarios['bono_anual_euros'].str.replace('€', ''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df_salarios['bono_anual_euros'] = (df_salarios['bono_anual_euros'].str.replace('€', ''))
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df_salarios['bono_anual_euros'] = (df_salarios['bono_anual_euros'].astype(float))

# %%
df_salarios[df_salarios['bono_anual_euros'].isna()]
# Out:
# Empty DataFrame
# Columns: [nombre, apellido, edad, pais, educacion_universitaria, nombre_de_la_empresa, cargo, anos_en_la_empresa, sueldo_anual_dolares, bono_anual_euros]
# Index: []

# %%
df_salarios[['sueldo_anual_dolares', 'bono_anual_euros']].head()
# Out:
#   sueldo_anual_dolares  bono_anual_euros
# 0                71841            4981.0
# 1               142115            1252.0
# 2                92278            5262.0
# 3                97130            3671.0
# 4                61413           10190.0

# %% [markdown]
# ---
# ## 4 · Detección y manejo de valores nulos
# ### 4.1 Contar nulos por columna

# %%
df_salarios.isnull().sum()
# Out:
# nombre                     0
# apellido                   0
# edad                       0
# pais                       1
# educacion_universitaria    0
# nombre_de_la_empresa       8
# cargo                      0
# anos_en_la_empresa         0
# sueldo_anual_dolares       0
# bono_anual_euros           0
# dtype: int64

# %% [markdown]
# > **Estrategias comunes:**
# - **Eliminar** filas/columnas con muchos nulos (`dropna`).
# - **Imputar** con media/mediana/moda (`fillna`).
# - **Revisar** si los nulos tienen significado en tu análisis.

# %% [markdown]
# Revisemos el caso de la columna `['pais']`

# %%
# columna pais
df_salarios[df_salarios['pais'].isna()]
# Out:
#     nombre apellido  edad pais educacion_universitaria nombre_de_la_empresa  \
# 300    Ana    Pérez    51  NaN                      No               Oracle
#
#                cargo  anos_en_la_empresa sueldo_anual_dolares  \
# 300  Project Manager                   2                67999
#
#      bono_anual_euros
# 300           12035.0

# %%
df_salarios = df_salarios.dropna(subset=["pais"])

# %%
df_salarios.isnull().sum()
# Out:
# nombre                     0
# apellido                   0
# edad                       0
# pais                       0
# educacion_universitaria    0
# nombre_de_la_empresa       8
# cargo                      0
# anos_en_la_empresa         0
# sueldo_anual_dolares       0
# bono_anual_euros           0
# dtype: int64

# %%
#pais sin valores nulos ya

# %% [markdown]
# Ahora revisemos el caso de la columna `["nombre_de_la_empresa"]`

# %%
df_salarios[df_salarios["nombre_de_la_empresa"].isna()]
# Out:
#         nombre  apellido  edad        pais educacion_universitaria  \
# 303  Valentina      Ríos    50       Chile                      No
# 304      Pedro      Díaz    59    Colombia                      Sí
# 305      Paula      Díaz    53  Costa Rica                      No
# 314       Luis   Ramírez    60   Argentina                      No
# 315       José  Martínez    35       Chile                      Sí
# 316     Carlos    Flores    55     Uruguay                      Sí
# 317      Lucía    Torres    36  Costa Rica                      No
# 318      Lucía  González    56     Uruguay                      No
#
#     nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 303                  NaN           Python Developer                   8
# 304                  NaN       AI Software Engineer                   9
# 305                  NaN  Machine Learning Engineer                  10
# 314                  NaN             Data Scientist                   4
# 315                  NaN              Data Engineer                   3
# 316                  NaN  Machine Learning Engineer                   1
# 317                  NaN          Software Engineer                   0
# 318                  NaN             Data Scientist                   7
#
#     sueldo_anual_dolares  bono_anual_euros
# 303                50138            3937.0
# 304               133052            5600.0
# 305                                 9874.0
# 314                72011            6723.0
# 315                97114            1684.0
# 316               104541            3128.0
# 317                86042            8746.0
# 318                96078           11419.0

# %% [markdown]
# No es necesario eliminar esos datos, pues podemos clasificarlos como `"Empresa Desconocida"`

# %%
# llenar desconocidos con "Empresa Desconocida"
df_salarios["nombre_de_la_empresa"].fillna("Empresa Desconocida")
# Out:
# 0      Mercado Libre
# 1             Amazon
# 2           Facebook
# 3      Mercado Libre
# 4             Amazon
#            ...
# 320          Globant
# 321          Globant
# 322           Oracle
# 323           Nubank
# 324             Meta
# Name: nombre_de_la_empresa, Length: 324, dtype: object

# %%
df_salarios[df_salarios["nombre_de_la_empresa"].isna()]
# Out:
# Empty DataFrame
# Columns: [nombre, apellido, edad, pais, educacion_universitaria, nombre_de_la_empresa, cargo, anos_en_la_empresa, sueldo_anual_dolares, bono_anual_euros]
# Index: []

# %%
df_salarios.isnull().sum()
# Out:
# nombre                     0
# apellido                   0
# edad                       0
# pais                       0
# educacion_universitaria    0
# nombre_de_la_empresa       0
# cargo                      0
# anos_en_la_empresa         0
# sueldo_anual_dolares       0
# bono_anual_euros           0
# dtype: int64

# %% [markdown]
# Revisemos el caso de `["sueldo_anual_dolares"]`

# %%
df_salarios[df_salarios["sueldo_anual_dolares"].isna()]
# Out:
# Empty DataFrame
# Columns: [nombre, apellido, edad, pais, educacion_universitaria, nombre_de_la_empresa, cargo, anos_en_la_empresa, sueldo_anual_dolares, bono_anual_euros]
# Index: []

# %% [markdown]
# Al no existir el registro de sueldos, la decision que tomamos fue eliminar esas filas con `dropna()`

# %%
df_salarios = df_salarios.dropna(subset=["sueldo_anual_dolares"])

# %%
df_salarios.isnull().sum()
# Out:
# nombre                     0
# apellido                   0
# edad                       0
# pais                       0
# educacion_universitaria    0
# nombre_de_la_empresa       0
# cargo                      0
# anos_en_la_empresa         0
# sueldo_anual_dolares       0
# bono_anual_euros           0
# dtype: int64

# %% [markdown]
# Ahora no tenemos valores nulos

# %% [markdown]
# ---
# ## 5 · Detección y manejo de duplicados
# Buscamos registros exactos repetidos.

# %%
duplicados = df_salarios.duplicated()# escribe tu codigo aqui
print(f'Duplicados encontrados: {duplicados.sum()}')
# Out:
# Duplicados encontrados: 10

# %%
df_salarios = df_salarios.drop_duplicates()

# %%
duplicados = df_salarios.duplicated()
print(f'Duplicados encontrados: {duplicados.sum()}')
# Out:
# Duplicados encontrados: 0

# %%
df_salarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 314 entries, 0 to 318
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nombre                   314 non-null    object
#  1   apellido                 314 non-null    object
#  2   edad                     314 non-null    int64
#  3   pais                     314 non-null    object
#  4   educacion_universitaria  314 non-null    object
#  5   nombre_de_la_empresa     314 non-null    object
#  6   cargo                    314 non-null    object
#  7   anos_en_la_empresa       314 non-null    int64
#  8   sueldo_anual_dolares     314 non-null    object
#  9   bono_anual_euros         314 non-null    float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 27.0+ KB

# %% [markdown]
# ### 🔢 Reiniciar índices
# `reset_index(drop=True)` crea un nuevo índice consecutivo (0 → n-1) y descarta el índice anterior.
# Útil después de eliminar filas o reordenar el DataFrame para evitar huecos o duplicados en la numeración.

# %%
df_salarios = df_salarios.reset_index(drop=True)

# %%
df_salarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nombre                   314 non-null    object
#  1   apellido                 314 non-null    object
#  2   edad                     314 non-null    int64
#  3   pais                     314 non-null    object
#  4   educacion_universitaria  314 non-null    object
#  5   nombre_de_la_empresa     314 non-null    object
#  6   cargo                    314 non-null    object
#  7   anos_en_la_empresa       314 non-null    int64
#  8   sueldo_anual_dolares     314 non-null    object
#  9   bono_anual_euros         314 non-null    float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 24.7+ KB

# %% [markdown]
# ### 💱 Conversión de Euros a Dólares
# Definimos una **tasa de cambio fija** `TASA_EUR_USD = 1.10` (1 € → 1.10 US$)
# y creamos la columna `bono_anual_dolares` multiplicando cada valor en
# `bono_anual_euros` por esa tasa. Esta operación es vectorizada: se aplica
# a toda la columna sin necesidad de bucles y deja ambos montos disponibles
# para comparaciones o visualizaciones futuras.

# %%
df_salarios.head()
# Out:
#      nombre apellido  edad      pais educacion_universitaria  \
# 0      José    López    36     Chile                      Sí
# 1  Fernanda   Vargas    39     Chile                      Sí
# 2  Fernanda  Ramírez    30  Colombia                      No
# 3      José    Gómez    35     Chile                      Sí
# 4       Ana    Pérez    32    Panamá                      No
#
#   nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 0        Mercado Libre           Python Developer                   2
# 1               Amazon       AI Software Engineer                   2
# 2             Facebook  Machine Learning Engineer                   2
# 3        Mercado Libre           Python Developer                  12
# 4               Amazon            Project Manager                   2
#
#   sueldo_anual_dolares  bono_anual_euros
# 0                71841            4981.0
# 1               142115            1252.0
# 2                92278            5262.0
# 3                97130            3671.0
# 4                61413           10190.0

# %%
# 1 € ≈ 1.10 USD
TASA_EUR_USD = 1.10

# %%
df_salarios["bono_anual_dolares"] = (
    df_salarios["bono_anual_euros"] * TASA_EUR_USD
)

# %%
df_salarios[["bono_anual_euros", "bono_anual_dolares"]]
# Out:
#      bono_anual_euros  bono_anual_dolares
# 0              4981.0              5479.1
# 1              1252.0              1377.2
# 2              5262.0              5788.2
# 3              3671.0              4038.1
# 4             10190.0             11209.0
# ..                ...                 ...
# 309            6723.0              7395.3
# 310            1684.0              1852.4
# 311            3128.0              3440.8
# 312            8746.0              9620.6
# 313           11419.0             12560.9
#
# [314 rows x 2 columns]

# %% [markdown]
# ### 📏 Ajuste de precisión
# Redondeamos `bono_anual_dolares` a **una cifra decimal** (`round(1)`) para
# homogeneizar el formato de los valores monetarios y evitar “ruido” de
# centavos insignificantes al presentar o agrupar los datos.

# %%
# redondear a 1 decimal bono_anual_dolares
df_salarios["bono_anual_dolares"] = df_salarios["bono_anual_dolares"].round(1)

# %%
df_salarios[["bono_anual_euros", "bono_anual_dolares"]]
# Out:
#      bono_anual_euros  bono_anual_dolares
# 0              4981.0              5479.1
# 1              1252.0              1377.2
# 2              5262.0              5788.2
# 3              3671.0              4038.1
# 4             10190.0             11209.0
# ..                ...                 ...
# 309            6723.0              7395.3
# 310            1684.0              1852.4
# 311            3128.0              3440.8
# 312            8746.0              9620.6
# 313           11419.0             12560.9
#
# [314 rows x 2 columns]

# %%
df_salarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nombre                   314 non-null    object
#  1   apellido                 314 non-null    object
#  2   edad                     314 non-null    int64
#  3   pais                     314 non-null    object
#  4   educacion_universitaria  314 non-null    object
#  5   nombre_de_la_empresa     314 non-null    object
#  6   cargo                    314 non-null    object
#  7   anos_en_la_empresa       314 non-null    int64
#  8   sueldo_anual_dolares     314 non-null    object
#  9   bono_anual_euros         314 non-null    float64
#  10  bono_anual_dolares       314 non-null    float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 27.1+ KB

# %% [markdown]
# ## 6 · Cargar el dataframe de países

# %%
#definir un path o ruta con Path
path_paises = DATA_RAW_DIR / "paises.csv"
path_paises = str(path_paises)

print(f"Ruta del archivo paises: {path_paises}")
print(f"existe archivo paises: {Path(path_paises).exists()}")
# Out:
# Ruta del archivo paises: C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\raw\paises.csv
# existe archivo paises: True

# %%
df_paises = pd.read_csv(filepath_or_buffer=path_paises, sep=',', encoding='utf-8')

# %%
df_paises.head()
# Out:
#         pais           capital  cantidad_de_habitantes                 PIB  \
# 0  Argentina      Buenos Aires                45376763    $641,000,000,000
# 1     Brasil          Brasilia               214326223  $2,000,000,000,000
# 2      Chile          Santiago                19116209    $317,000,000,000
# 3   Colombia            Bogotá                51874024    $343,000,000,000
# 4     México  Ciudad de México               126014024  $1,410,000,000,000
#
#   ingreso_per_capita
# 0            $14,120
# 1             $9,334
# 2            $16,580
# 3             $6,611
# 4            $11,190

# %%
df_paises['pais'].unique()
# Out:
# array(['Argentina', 'Brasil', 'Chile', 'Colombia', 'México', 'Perú',
#        'Uruguay', 'Panamá', 'Ecuador', 'Bolivia'], dtype=object)

# %%
df_paises['pais'].nunique()
# Out:
# 10

# %%
df_salarios['pais'].unique()
# Out:
# array(['Chile', 'Colombia', 'Panamá', 'Costa Rica', 'México', 'Uruguay',
#        'Argentina', 'Perú'], dtype=object)

# %%
df_salarios['pais'].nunique()
# Out:
# 8

# %%
paises_en_df_paises = set(df_paises["pais"])
paises_en_df_paises
# Out:
# {'Argentina',
#  'Bolivia',
#  'Brasil',
#  'Chile',
#  'Colombia',
#  'Ecuador',
#  'México',
#  'Panamá',
#  'Perú',
#  'Uruguay'}

# %%
paises_en_df_salarios = set(df_salarios["pais"])
paises_en_df_salarios
# Out:
# {'Argentina',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'México',
#  'Panamá',
#  'Perú',
#  'Uruguay'}

# %% [markdown]
# ### 🔍 Identificar discrepancias entre DataFrames
#
# 1. **`paises_faltantes_en_df_paises`**
#    Conjunto de países que **están en `df_paises` pero no aparecen** en `df_salarios`.
#
# 2. **`paises_faltantes_en_df_salarios`**
#    Conjunto inverso: países presentes en `df_salarios`, ausentes en `df_paises`.
#
# 3. **`paises_faltantes`**
#    Unión (`|`) de ambos conjuntos → lista global de **todos los países que no coinciden** entre los dos DataFrames.
#    Útil para decidir si imputar, descartar o investigar la fuente de datos.

# %%
paises_faltantes_en_df_paises = paises_en_df_paises - paises_en_df_salarios
paises_faltantes_en_df_paises
# Out:
# {'Bolivia', 'Brasil', 'Ecuador'}

# %%
paises_faltantes_en_df_salarios =  paises_en_df_salarios - paises_en_df_paises
paises_faltantes_en_df_salarios
# Out:
# {'Costa Rica'}

# %%
paises_faltantes = paises_faltantes_en_df_paises | paises_faltantes_en_df_salarios
paises_faltantes
# Out:
# {'Bolivia', 'Brasil', 'Costa Rica', 'Ecuador'}

# %%
df_paises[df_paises['pais'].isin(paises_faltantes)]
# Out:
#       pais   capital  cantidad_de_habitantes                 PIB  \
# 1   Brasil  Brasilia               214326223  $2,000,000,000,000
# 8  Ecuador     Quito                18001000    $118,000,000,000
# 9  Bolivia    La Paz                12456000     $44,000,000,000
#
#   ingreso_per_capita
# 1             $9,334
# 8             $6,556
# 9             $3,530

# %% [markdown]
# ### 🗑️ Eliminar registros específicos
# Usamos `drop(index=[1, 8, 9])` para remover las filas cuyo índice es 1, 8 y 9
# (Brasil, Ecuador y Bolivia en este caso). Esto excluye esos países del
# DataFrame `df_paises` antes de realizar uniones o análisis posteriores.

# %%
# eliminar registros 1 8 9 
df_paises = df_paises.drop(index=[1, 8, 9])

# %%
df_paises.reset_index(drop=True, inplace=True)

# %%
df_paises
# Out:
#         pais           capital  cantidad_de_habitantes                 PIB  \
# 0  Argentina      Buenos Aires                45376763    $641,000,000,000
# 1      Chile          Santiago                19116209    $317,000,000,000
# 2   Colombia            Bogotá                51874024    $343,000,000,000
# 3     México  Ciudad de México               126014024  $1,410,000,000,000
# 4       Perú              Lima                33925854    $268,000,000,000
# 5    Uruguay        Montevideo                 3518552     $71,000,000,000
# 6     Panamá  Ciudad de Panamá                 4468000     $76,000,000,000
#
#   ingreso_per_capita
# 0            $14,120
# 1            $16,580
# 2             $6,611
# 3            $11,190
# 4             $7,900
# 5            $20,300
# 6            $16,995

# %% [markdown]
# ### 💲 Limpieza y conversión de columnas monetarias
# Seleccionamos las columnas `PIB` e `ingreso_per_capita` y:
#
# 1. **`replace({'\\$': '', ',': ''}, regex=True)`**
#    - Elimina el símbolo de dólar (`$`) y las comas de miles (`,`).
#    - `regex=True` permite usar patrones de expresión regular.
#
# 2. **`astype(float)`**
#    - Convierte las cadenas ya limpias a valores numéricos (`float64`).
#
# Resultado: ambas columnas quedan listas para cálculos y comparaciones
# estadísticas sin símbolos ni separadores.

# %%
df_paises[["PIB", "ingreso_per_capita"]] = (df_paises[["PIB", "ingreso_per_capita"]].replace({'\\$': '', ',': ''}, regex=True).astype(float))

# %%
df_paises.head()
# Out:
#         pais           capital  cantidad_de_habitantes           PIB  \
# 0  Argentina      Buenos Aires                45376763  6.410000e+11
# 1      Chile          Santiago                19116209  3.170000e+11
# 2   Colombia            Bogotá                51874024  3.430000e+11
# 3     México  Ciudad de México               126014024  1.410000e+12
# 4       Perú              Lima                33925854  2.680000e+11
#
#    ingreso_per_capita
# 0             14120.0
# 1             16580.0
# 2              6611.0
# 3             11190.0
# 4              7900.0

# %%
df_paises.isnull().sum()
# Out:
# pais                      0
# capital                   0
# cantidad_de_habitantes    0
# PIB                       0
# ingreso_per_capita        0
# dtype: int64

# %% [markdown]
# ---
# ## 7 · Unir datasets (`merge`)
# Unimos `df_salarios` con `df_paises` por la columna `pais` para enriquecer la información.

# %%
# unir datasets de salarios y paises por culumna pais
df_salarios_pais = pd.merge(df_salarios, df_paises, on="pais", how="left").reset_index(drop=True)

# %%
df_salarios_pais.head()
# Out:
#      nombre apellido  edad        pais educacion_universitaria  \
# 0      José    López    36       Chile                      Sí
# 1  Fernanda  Ramírez    30    Colombia                      No
# 2      José    Gómez    35       Chile                      Sí
# 3       Ana    Pérez    32      Panamá                      No
# 4    Andrea   Torres    45  Costa Rica                      No
#
#   nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 0        Mercado Libre           Python Developer                   2
# 1             Facebook  Machine Learning Engineer                   2
# 2        Mercado Libre           Python Developer                  12
# 3               Amazon            Project Manager                   2
# 4        Mercado Libre              Data Engineer                   8
#
#   sueldo_anual_dolares  bono_anual_euros  bono_anual_dolares  \
# 0                71841            4981.0              5479.1
# 1                92278            5262.0              5788.2
# 2                97130            3671.0              4038.1
# 3                61413           10190.0             11209.0
# 4                84987            5493.0              6042.3
#
#             capital  cantidad_de_habitantes           PIB  ingreso_per_capita
# 0          Santiago              19116209.0  3.170000e+11             16580.0
# 1            Bogotá              51874024.0  3.430000e+11              6611.0
# 2          Santiago              19116209.0  3.170000e+11             16580.0
# 3  Ciudad de Panamá               4468000.0  7.600000e+10             16995.0
# 4               NaN                     NaN           NaN                 NaN

# %% [markdown]
# ---
# ## 8 · Crear columnas derivadas

# %% [markdown]
# ### 💰 Métrica de compensación total
# Creamos `compensacion_total` sumando el salario anual (`sueldo_anual_dolares`)
# y el bono anual convertido a dólares (`bono_anual_dolares`).
# Esta columna refleja cuánto percibe realmente cada empleado en un año,
# facilitando análisis comparativos por país, cargo o empresa.

# %%
# crear columna de sueldo anual en euros
df_salarios_pais["compensacion_total"] = df_salarios_pais["sueldo_anual_dolares"] + df_salarios_pais["bono_anual_dolares"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: can only concatenate str (not "float") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 2
#       1 # crear columna de sueldo anual en euros
# ----> 2 df_salarios_pais["compensacion_total"] = df_salarios_pais["sueldo_anual_dolares"] + df_salarios_pais["bono_anual_dolares"]
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)    184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\ops\array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)    225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\ops\array_ops.py:163, in _masked_arith_op(x, y, op)
#     161     # See GH#5284, GH#5035, GH#19448 for historical reference
#     162     if mask.any():
# --> 163         result[mask] = op(xrav[mask], yrav[mask])
#     165 else:
#     166     if not is_scalar(y):
#
# TypeError: can only concatenate str (not "float") to str

# %%
import numpy as np
import pandas as pd

# ────────────────────────────────────────────────────────────
# BLOQUE ÚNICO: limpieza + conversión + nueva columna
# ────────────────────────────────────────────────────────────

# 0) Asegúrate de tener los nombres correctos (solo se ejecuta 1ª vez)
df_salarios_pais.rename(
    columns={
        "sueldo_anual": "sueldo_anual_dolares",
        "bono_anual":   "bono_anual_dolares"
    },
    inplace=True
)

# 1) Lista de columnas que deben ser numéricas
cols = ["sueldo_anual_dolares", "bono_anual_dolares"]

# 2) LIMPIEZA y CONVERSIÓN en un solo paso
df_salarios_pais[cols] = (
    df_salarios_pais[cols]
      .astype(str)                               # fuerza string para usar str.*
      .replace({r"[^\d\.\-]": ""}, regex=True)   # mantiene solo dígitos, punto y signo
      .replace("", np.nan)                       # strings vacíos → NaN
      .apply(pd.to_numeric, errors="coerce")     # convierte; errores → NaN
)

# 3) CREAR 'compensacion_total'
#    (llena NaN con 0; cámbialo por .dropna(...) si prefieres eliminar filas incompletas)
df_salarios_pais["compensacion_total"] = (
    df_salarios_pais["sueldo_anual_dolares"].fillna(0) +
    df_salarios_pais["bono_anual_dolares"].fillna(0)
)

# 4) COMPROBACIÓN rápida (puedes comentarla luego)
print(df_salarios_pais[cols + ["compensacion_total"]].dtypes)
print(df_salarios_pais[cols + ["compensacion_total"]].head())
# Out:
# sueldo_anual_dolares    float64
# bono_anual_dolares      float64
# compensacion_total      float64
# dtype: object
#    sueldo_anual_dolares  bono_anual_dolares  compensacion_total
# 0               71841.0              5479.1             77320.1
# 1               92278.0              5788.2             98066.2
# 2               97130.0              4038.1            101168.1
# 3               61413.0             11209.0             72622.0
# 4               84987.0              6042.3             91029.3

# %%
df_salarios_pais.head()
# Out:
#      nombre apellido  edad        pais educacion_universitaria  \
# 0      José    López    36       Chile                      Sí
# 1  Fernanda  Ramírez    30    Colombia                      No
# 2      José    Gómez    35       Chile                      Sí
# 3       Ana    Pérez    32      Panamá                      No
# 4    Andrea   Torres    45  Costa Rica                      No
#
#   nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 0        Mercado Libre           Python Developer                   2
# 1             Facebook  Machine Learning Engineer                   2
# 2        Mercado Libre           Python Developer                  12
# 3               Amazon            Project Manager                   2
# 4        Mercado Libre              Data Engineer                   8
#
#    sueldo_anual_dolares  bono_anual_euros  bono_anual_dolares  \
# 0               71841.0            4981.0              5479.1
# 1               92278.0            5262.0              5788.2
# 2               97130.0            3671.0              4038.1
# 3               61413.0           10190.0             11209.0
# 4               84987.0            5493.0              6042.3
#
#             capital  cantidad_de_habitantes           PIB  ingreso_per_capita  \
# 0          Santiago              19116209.0  3.170000e+11             16580.0
# 1            Bogotá              51874024.0  3.430000e+11              6611.0
# 2          Santiago              19116209.0  3.170000e+11             16580.0
# 3  Ciudad de Panamá               4468000.0  7.600000e+10             16995.0
# 4               NaN                     NaN           NaN                 NaN
#
#    compensacion_total
# 0             77320.1
# 1             98066.2
# 2            101168.1
# 3             72622.0
# 4             91029.3

# %% [markdown]
# ### 🏆 Clasificación de senioridad
# Creamos la columna `senioridad` con `np.where`:
#
# * **Condición** → `anos_en_la_empresa > 5`
#   - Si el empleado lleva **más de 5 años**, se le etiqueta como **"Senior"**.
#   - En caso contrario, se marca como **"Junior"**.
#
# Así obtenemos una variable categórica que nos ayudará a comparar
# compensaciones y otros indicadores entre niveles de experiencia.

# %%
# nueva columna de anos_en_la_empresa   Senior empleado con mas de 5 años
df_salarios_pais["senioridad"] =np.where(df_salarios_pais["anos_en_la_empresa"] > 5,"Senior","Junior")

# %%
df_salarios_pais[['nombre', 'apellido', 'anos_en_la_empresa','compensacion_total', 'senioridad']].head(10)
# Out:
#      nombre apellido  anos_en_la_empresa  compensacion_total senioridad
# 0      José    López                   2             77320.1     Junior
# 1  Fernanda  Ramírez                   2             98066.2     Junior
# 2      José    Gómez                  12            101168.1     Senior
# 3       Ana    Pérez                   2             72622.0     Junior
# 4    Andrea   Torres                   8             91029.3     Senior
# 5    Andrea   Vargas                   9            102338.1     Senior
# 6     Pedro  Herrera                   1            164982.1     Junior
# 7      José    Pérez                  10             88411.6     Senior
# 8      Juan   Torres                   7             88621.2     Senior
# 9    Camila   Flores                   2             37164.7     Junior

# %% [markdown]
# ### 🔎 Revisión de valores nulos por columna
# `df_salarios_pais.isna().sum()` muestra cuántos `NaN` hay en cada columna
# tras el merge. Los resultados indican que los registros de **Costa Rica**
# aún presentan nulos en `capital`, `PIB`, `cantidad_de_habitantes` e
# `ingreso_per_capita`. Conviene imputar o investigar estos campos antes de
# continuar con el análisis para evitar sesgos o errores en cálculos agregados.

# %%
df_salarios_pais.isna().sum()
# Out:
# nombre                      0
# apellido                    0
# edad                        0
# pais                        0
# educacion_universitaria     0
# nombre_de_la_empresa        0
# cargo                       0
# anos_en_la_empresa          0
# sueldo_anual_dolares        7
# bono_anual_euros            0
# bono_anual_dolares          0
# capital                    41
# cantidad_de_habitantes     41
# PIB                        41
# ingreso_per_capita         41
# compensacion_total          0
# senioridad                  0
# dtype: int64

# %%
df_salarios_pais[df_salarios_pais['pais'] == 'Costa Rica']
# Out:
#         nombre   apellido  edad        pais educacion_universitaria  \
# 4       Andrea     Torres    45  Costa Rica                      No
# 13    Fernanda       Ríos    23  Costa Rica                      Sí
# 18       Pedro    Ramírez    54  Costa Rica                      Sí
# 20       Pedro     Torres    22  Costa Rica                      Sí
# 29      Carlos    Herrera    53  Costa Rica                      No
# 31    Fernanda       Díaz    38  Costa Rica                      No
# 32       Diego   González    40  Costa Rica                      No
# 38       Lucía      López    49  Costa Rica                      Sí
# 42       Pedro     Vargas    28  Costa Rica                      No
# 48    Fernanda     Torres    47  Costa Rica                      Sí
# 58      Javier       Díaz    23  Costa Rica                      Sí
# 82      Carlos     Vargas    51  Costa Rica                      No
# 94        Juan   González    56  Costa Rica                      Sí
# 105        Ana      Pérez    42  Costa Rica                      Sí
# 113  Valentina   Martínez    45  Costa Rica                      Sí
# 116      Pedro    Morales    37  Costa Rica                      No
# 131     Andrea      López    38  Costa Rica                      No
# 136   Fernanda  Rodríguez    49  Costa Rica                      Sí
# 140       Luis    Herrera    32  Costa Rica                      Sí
# 141     Carlos     Torres    43  Costa Rica                      No
# 155       José       Díaz    27  Costa Rica                      Sí
# 197        Ana       Ríos    54  Costa Rica                      No
# 205      Pedro      Gómez    40  Costa Rica                      Sí
# 225     Camila  Rodríguez    48  Costa Rica                      Sí
# 226     Javier     Flores    24  Costa Rica                      No
# 227     Camila   Martínez    38  Costa Rica                      Sí
# 228      Lucía      Gómez    32  Costa Rica                      Sí
# 229   Fernanda    Morales    49  Costa Rica                      Sí
# 240     Camila   González    29  Costa Rica                      No
# 244   Fernanda     Vargas    34  Costa Rica                      No
# 254       Juan       Díaz    23  Costa Rica                      No
# 256        Ana     Torres    52  Costa Rica                      Sí
# 258     Carlos      Gómez    42  Costa Rica                      Sí
# 265      Lucía     Torres    36  Costa Rica                      No
# 271      Pedro     Torres    50  Costa Rica                      No
# 281       Juan    Herrera    60  Costa Rica                      No
# 291      Paula       Díaz    53  Costa Rica                      No
# 294       Juan    Morales    49  Costa Rica                      No
# 300      Paula       Díaz    53  Costa Rica                      No
# 303       Juan    Morales    49  Costa Rica                      No
# 309      Lucía     Torres    36  Costa Rica                      No
#
#     nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 4          Mercado Libre              Data Engineer                   8
# 13                Oracle              Data Engineer                  10
# 18             Microsoft  Machine Learning Engineer                   2
# 20              Facebook       AI Software Engineer                   6
# 29                 Rappi             Data Scientist                   4
# 31                Oracle            Project Manager                   0
# 32               Globant  Machine Learning Engineer                  12
# 38                  Meta             Data Scientist                  13
# 42              Facebook               Data Analyst                   8
# 48                Google              Product Owner                   7
# 58                Google              Product Owner                   4
# 82                Oracle          Software Engineer                  13
# 94                 Rappi              Product Owner                  10
# 105             Facebook               Data Analyst                   0
# 113        Mercado Libre  Machine Learning Engineer                  13
# 116             Facebook              Data Engineer                   9
# 131               Amazon       AI Software Engineer                  12
# 136               Google            Project Manager                  10
# 140                 Meta       AI Software Engineer                  11
# 141        Mercado Libre  Machine Learning Engineer                   5
# 155                Rappi  Machine Learning Engineer                   2
# 197        Mercado Libre              Product Owner                   6
# 205        Mercado Libre               Data Analyst                  12
# 225                 Meta  Machine Learning Engineer                  12
# 226            Microsoft              Data Engineer                  13
# 227        Mercado Libre          Software Engineer                   4
# 228               Google             Data Scientist                   1
# 229                 Meta            Project Manager                  10
# 240              Globant               Data Analyst                   9
# 244                Rappi             Data Scientist                   7
# 254            Microsoft               Data Analyst                   6
# 256               Google            Project Manager                   5
# 258               Nubank          Software Engineer                  11
# 265               Oracle          Software Engineer                   0
# 271            Microsoft          Software Engineer                   2
# 281                Rappi          Software Engineer                   5
# 291                Rappi  Machine Learning Engineer                  10
# 294               Amazon          Software Engineer                   2
# 300  Empresa Desconocida  Machine Learning Engineer                  10
# 303               Amazon          Software Engineer                   2
# 309  Empresa Desconocida          Software Engineer                   0
#
#      sueldo_anual_dolares  bono_anual_euros  bono_anual_dolares capital  \
# 4                 84987.0            5493.0              6042.3     NaN
# 13                97616.0            8345.0              9179.5     NaN
# 18               101737.0            9828.0             10810.8     NaN
# 20               115269.0           10657.0             11722.7     NaN
# 29                79861.0            7554.0              8309.4     NaN
# 31                89704.0            7063.0              7769.3     NaN
# 32               104739.0           11879.0             13066.9     NaN
# 38                61352.0            7054.0              7759.4     NaN
# 42                56598.0            3690.0              4059.0     NaN
# 48                87181.0            7291.0              8020.1     NaN
# 58                88256.0            8127.0              8939.7     NaN
# 82                62222.0            6344.0              6978.4     NaN
# 94                84204.0            7141.0              7855.1     NaN
# 105               58240.0           13017.0             14318.7     NaN
# 113               76052.0           10565.0             11621.5     NaN
# 116               69770.0            2575.0              2832.5     NaN
# 131               82980.0            5820.0              6402.0     NaN
# 136               50469.0            9026.0              9928.6     NaN
# 140              153058.0            9289.0             10217.9     NaN
# 141               97410.0            9042.0              9946.2     NaN
# 155              100670.0           12139.0             13352.9     NaN
# 197               60847.0            7323.0              8055.3     NaN
# 205               39407.0            7610.0              8371.0     NaN
# 225               73296.0            2801.0              3081.1     NaN
# 226               91907.0            6232.0              6855.2     NaN
# 227              129692.0            8990.0              9889.0     NaN
# 228               60620.0           12187.0             13405.7     NaN
# 229               56879.0            1962.0              2158.2     NaN
# 240               45300.0            6266.0              6892.6     NaN
# 244               80431.0            4863.0              5349.3     NaN
# 254               59946.0           11829.0             13011.9     NaN
# 256               80607.0           13993.0             15392.3     NaN
# 258              114949.0            5702.0              6272.2     NaN
# 265               86042.0            8746.0              9620.6     NaN
# 271               81151.0            9864.0             10850.4     NaN
# 281              127936.0            1250.0              1375.0     NaN
# 291               70039.0            9874.0             10861.4     NaN
# 294              120868.0           12223.0             13445.3     NaN
# 300                   NaN            9874.0             10861.4     NaN
# 303                   NaN           12223.0             13445.3     NaN
# 309               86042.0            8746.0              9620.6     NaN
#
#      cantidad_de_habitantes  PIB  ingreso_per_capita  compensacion_total  \
# 4                       NaN  NaN                 NaN             91029.3
# 13                      NaN  NaN                 NaN            106795.5
# 18                      NaN  NaN                 NaN            112547.8
# 20                      NaN  NaN                 NaN            126991.7
# 29                      NaN  NaN                 NaN             88170.4
# 31                      NaN  NaN                 NaN             97473.3
# 32                      NaN  NaN                 NaN            117805.9
# 38                      NaN  NaN                 NaN             69111.4
# 42                      NaN  NaN                 NaN             60657.0
# 48                      NaN  NaN                 NaN             95201.1
# 58                      NaN  NaN                 NaN             97195.7
# 82                      NaN  NaN                 NaN             69200.4
# 94                      NaN  NaN                 NaN             92059.1
# 105                     NaN  NaN                 NaN             72558.7
# 113                     NaN  NaN                 NaN             87673.5
# 116                     NaN  NaN                 NaN             72602.5
# 131                     NaN  NaN                 NaN             89382.0
# 136                     NaN  NaN                 NaN             60397.6
# 140                     NaN  NaN                 NaN            163275.9
# 141                     NaN  NaN                 NaN            107356.2
# 155                     NaN  NaN                 NaN            114022.9
# 197                     NaN  NaN                 NaN             68902.3
# 205                     NaN  NaN                 NaN             47778.0
# 225                     NaN  NaN                 NaN             76377.1
# 226                     NaN  NaN                 NaN             98762.2
# 227                     NaN  NaN                 NaN            139581.0
# 228                     NaN  NaN                 NaN             74025.7
# 229                     NaN  NaN                 NaN             59037.2
# 240                     NaN  NaN                 NaN             52192.6
# 244                     NaN  NaN                 NaN             85780.3
# 254                     NaN  NaN                 NaN             72957.9
# 256                     NaN  NaN                 NaN             95999.3
# 258                     NaN  NaN                 NaN            121221.2
# 265                     NaN  NaN                 NaN             95662.6
# 271                     NaN  NaN                 NaN             92001.4
# 281                     NaN  NaN                 NaN            129311.0
# 291                     NaN  NaN                 NaN             80900.4
# 294                     NaN  NaN                 NaN            134313.3
# 300                     NaN  NaN                 NaN             10861.4
# 303                     NaN  NaN                 NaN             13445.3
# 309                     NaN  NaN                 NaN             95662.6
#
#     senioridad
# 4       Senior
# 13      Senior
# 18      Junior
# 20      Senior
# 29      Junior
# 31      Junior
# 32      Senior
# 38      Senior
# 42      Senior
# 48      Senior
# 58      Junior
# 82      Senior
# 94      Senior
# 105     Junior
# 113     Senior
# 116     Senior
# 131     Senior
# 136     Senior
# 140     Senior
# 141     Junior
# 155     Junior
# 197     Senior
# 205     Senior
# 225     Senior
# 226     Senior
# 227     Junior
# 228     Junior
# 229     Senior
# 240     Senior
# 244     Senior
# 254     Senior
# 256     Junior
# 258     Senior
# 265     Junior
# 271     Junior
# 281     Junior
# 291     Senior
# 294     Junior
# 300     Senior
# 303     Junior
# 309     Junior

# %% [markdown]
# ### 🔍 Filtrar filas de Costa Rica
# Creamos `mask_cr` para identificar las filas donde `pais == "Costa Rica"` y,
# con `loc`, mostramos únicamente esos registros. Así podemos inspeccionar
# qué columnas siguen con `NaN` y decidir cómo imputarlas o ajustarlas.

# %%
mask_cr = df_salarios_pais["pais"] == "Costa Rica"
df_salarios_pais.loc[mask_cr]
# Out:
#         nombre   apellido  edad        pais educacion_universitaria  \
# 4       Andrea     Torres    45  Costa Rica                      No
# 13    Fernanda       Ríos    23  Costa Rica                      Sí
# 18       Pedro    Ramírez    54  Costa Rica                      Sí
# 20       Pedro     Torres    22  Costa Rica                      Sí
# 29      Carlos    Herrera    53  Costa Rica                      No
# 31    Fernanda       Díaz    38  Costa Rica                      No
# 32       Diego   González    40  Costa Rica                      No
# 38       Lucía      López    49  Costa Rica                      Sí
# 42       Pedro     Vargas    28  Costa Rica                      No
# 48    Fernanda     Torres    47  Costa Rica                      Sí
# 58      Javier       Díaz    23  Costa Rica                      Sí
# 82      Carlos     Vargas    51  Costa Rica                      No
# 94        Juan   González    56  Costa Rica                      Sí
# 105        Ana      Pérez    42  Costa Rica                      Sí
# 113  Valentina   Martínez    45  Costa Rica                      Sí
# 116      Pedro    Morales    37  Costa Rica                      No
# 131     Andrea      López    38  Costa Rica                      No
# 136   Fernanda  Rodríguez    49  Costa Rica                      Sí
# 140       Luis    Herrera    32  Costa Rica                      Sí
# 141     Carlos     Torres    43  Costa Rica                      No
# 155       José       Díaz    27  Costa Rica                      Sí
# 197        Ana       Ríos    54  Costa Rica                      No
# 205      Pedro      Gómez    40  Costa Rica                      Sí
# 225     Camila  Rodríguez    48  Costa Rica                      Sí
# 226     Javier     Flores    24  Costa Rica                      No
# 227     Camila   Martínez    38  Costa Rica                      Sí
# 228      Lucía      Gómez    32  Costa Rica                      Sí
# 229   Fernanda    Morales    49  Costa Rica                      Sí
# 240     Camila   González    29  Costa Rica                      No
# 244   Fernanda     Vargas    34  Costa Rica                      No
# 254       Juan       Díaz    23  Costa Rica                      No
# 256        Ana     Torres    52  Costa Rica                      Sí
# 258     Carlos      Gómez    42  Costa Rica                      Sí
# 265      Lucía     Torres    36  Costa Rica                      No
# 271      Pedro     Torres    50  Costa Rica                      No
# 281       Juan    Herrera    60  Costa Rica                      No
# 291      Paula       Díaz    53  Costa Rica                      No
# 294       Juan    Morales    49  Costa Rica                      No
# 300      Paula       Díaz    53  Costa Rica                      No
# 303       Juan    Morales    49  Costa Rica                      No
# 309      Lucía     Torres    36  Costa Rica                      No
#
#     nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 4          Mercado Libre              Data Engineer                   8
# 13                Oracle              Data Engineer                  10
# 18             Microsoft  Machine Learning Engineer                   2
# 20              Facebook       AI Software Engineer                   6
# 29                 Rappi             Data Scientist                   4
# 31                Oracle            Project Manager                   0
# 32               Globant  Machine Learning Engineer                  12
# 38                  Meta             Data Scientist                  13
# 42              Facebook               Data Analyst                   8
# 48                Google              Product Owner                   7
# 58                Google              Product Owner                   4
# 82                Oracle          Software Engineer                  13
# 94                 Rappi              Product Owner                  10
# 105             Facebook               Data Analyst                   0
# 113        Mercado Libre  Machine Learning Engineer                  13
# 116             Facebook              Data Engineer                   9
# 131               Amazon       AI Software Engineer                  12
# 136               Google            Project Manager                  10
# 140                 Meta       AI Software Engineer                  11
# 141        Mercado Libre  Machine Learning Engineer                   5
# 155                Rappi  Machine Learning Engineer                   2
# 197        Mercado Libre              Product Owner                   6
# 205        Mercado Libre               Data Analyst                  12
# 225                 Meta  Machine Learning Engineer                  12
# 226            Microsoft              Data Engineer                  13
# 227        Mercado Libre          Software Engineer                   4
# 228               Google             Data Scientist                   1
# 229                 Meta            Project Manager                  10
# 240              Globant               Data Analyst                   9
# 244                Rappi             Data Scientist                   7
# 254            Microsoft               Data Analyst                   6
# 256               Google            Project Manager                   5
# 258               Nubank          Software Engineer                  11
# 265               Oracle          Software Engineer                   0
# 271            Microsoft          Software Engineer                   2
# 281                Rappi          Software Engineer                   5
# 291                Rappi  Machine Learning Engineer                  10
# 294               Amazon          Software Engineer                   2
# 300  Empresa Desconocida  Machine Learning Engineer                  10
# 303               Amazon          Software Engineer                   2
# 309  Empresa Desconocida          Software Engineer                   0
#
#      sueldo_anual_dolares  bono_anual_euros  bono_anual_dolares capital  \
# 4                 84987.0            5493.0              6042.3     NaN
# 13                97616.0            8345.0              9179.5     NaN
# 18               101737.0            9828.0             10810.8     NaN
# 20               115269.0           10657.0             11722.7     NaN
# 29                79861.0            7554.0              8309.4     NaN
# 31                89704.0            7063.0              7769.3     NaN
# 32               104739.0           11879.0             13066.9     NaN
# 38                61352.0            7054.0              7759.4     NaN
# 42                56598.0            3690.0              4059.0     NaN
# 48                87181.0            7291.0              8020.1     NaN
# 58                88256.0            8127.0              8939.7     NaN
# 82                62222.0            6344.0              6978.4     NaN
# 94                84204.0            7141.0              7855.1     NaN
# 105               58240.0           13017.0             14318.7     NaN
# 113               76052.0           10565.0             11621.5     NaN
# 116               69770.0            2575.0              2832.5     NaN
# 131               82980.0            5820.0              6402.0     NaN
# 136               50469.0            9026.0              9928.6     NaN
# 140              153058.0            9289.0             10217.9     NaN
# 141               97410.0            9042.0              9946.2     NaN
# 155              100670.0           12139.0             13352.9     NaN
# 197               60847.0            7323.0              8055.3     NaN
# 205               39407.0            7610.0              8371.0     NaN
# 225               73296.0            2801.0              3081.1     NaN
# 226               91907.0            6232.0              6855.2     NaN
# 227              129692.0            8990.0              9889.0     NaN
# 228               60620.0           12187.0             13405.7     NaN
# 229               56879.0            1962.0              2158.2     NaN
# 240               45300.0            6266.0              6892.6     NaN
# 244               80431.0            4863.0              5349.3     NaN
# 254               59946.0           11829.0             13011.9     NaN
# 256               80607.0           13993.0             15392.3     NaN
# 258              114949.0            5702.0              6272.2     NaN
# 265               86042.0            8746.0              9620.6     NaN
# 271               81151.0            9864.0             10850.4     NaN
# 281              127936.0            1250.0              1375.0     NaN
# 291               70039.0            9874.0             10861.4     NaN
# 294              120868.0           12223.0             13445.3     NaN
# 300                   NaN            9874.0             10861.4     NaN
# 303                   NaN           12223.0             13445.3     NaN
# 309               86042.0            8746.0              9620.6     NaN
#
#      cantidad_de_habitantes  PIB  ingreso_per_capita  compensacion_total  \
# 4                       NaN  NaN                 NaN             91029.3
# 13                      NaN  NaN                 NaN            106795.5
# 18                      NaN  NaN                 NaN            112547.8
# 20                      NaN  NaN                 NaN            126991.7
# 29                      NaN  NaN                 NaN             88170.4
# 31                      NaN  NaN                 NaN             97473.3
# 32                      NaN  NaN                 NaN            117805.9
# 38                      NaN  NaN                 NaN             69111.4
# 42                      NaN  NaN                 NaN             60657.0
# 48                      NaN  NaN                 NaN             95201.1
# 58                      NaN  NaN                 NaN             97195.7
# 82                      NaN  NaN                 NaN             69200.4
# 94                      NaN  NaN                 NaN             92059.1
# 105                     NaN  NaN                 NaN             72558.7
# 113                     NaN  NaN                 NaN             87673.5
# 116                     NaN  NaN                 NaN             72602.5
# 131                     NaN  NaN                 NaN             89382.0
# 136                     NaN  NaN                 NaN             60397.6
# 140                     NaN  NaN                 NaN            163275.9
# 141                     NaN  NaN                 NaN            107356.2
# 155                     NaN  NaN                 NaN            114022.9
# 197                     NaN  NaN                 NaN             68902.3
# 205                     NaN  NaN                 NaN             47778.0
# 225                     NaN  NaN                 NaN             76377.1
# 226                     NaN  NaN                 NaN             98762.2
# 227                     NaN  NaN                 NaN            139581.0
# 228                     NaN  NaN                 NaN             74025.7
# 229                     NaN  NaN                 NaN             59037.2
# 240                     NaN  NaN                 NaN             52192.6
# 244                     NaN  NaN                 NaN             85780.3
# 254                     NaN  NaN                 NaN             72957.9
# 256                     NaN  NaN                 NaN             95999.3
# 258                     NaN  NaN                 NaN            121221.2
# 265                     NaN  NaN                 NaN             95662.6
# 271                     NaN  NaN                 NaN             92001.4
# 281                     NaN  NaN                 NaN            129311.0
# 291                     NaN  NaN                 NaN             80900.4
# 294                     NaN  NaN                 NaN            134313.3
# 300                     NaN  NaN                 NaN             10861.4
# 303                     NaN  NaN                 NaN             13445.3
# 309                     NaN  NaN                 NaN             95662.6
#
#     senioridad
# 4       Senior
# 13      Senior
# 18      Junior
# 20      Senior
# 29      Junior
# 31      Junior
# 32      Senior
# 38      Senior
# 42      Senior
# 48      Senior
# 58      Junior
# 82      Senior
# 94      Senior
# 105     Junior
# 113     Senior
# 116     Senior
# 131     Senior
# 136     Senior
# 140     Senior
# 141     Junior
# 155     Junior
# 197     Senior
# 205     Senior
# 225     Senior
# 226     Senior
# 227     Junior
# 228     Junior
# 229     Senior
# 240     Senior
# 244     Senior
# 254     Senior
# 256     Junior
# 258     Senior
# 265     Junior
# 271     Junior
# 281     Junior
# 291     Senior
# 294     Junior
# 300     Senior
# 303     Junior
# 309     Junior

# %% [markdown]
# ### 📝 Diccionario con datos oficiales de Costa Rica
# Definimos `datos_cr` con los valores verificados para imputar en las filas
# de Costa Rica:
#
# * **capital:** San José
# * **cantidad_de_habitantes:** 5 150 000
# * **PIB:** 86 500 000 000 USD
# * **ingreso_per_capita:** 14 319 USD
#
# Estos números reemplazarán los `NaN` correspondientes en el DataFrame.

# %%
datos_cr = {
    "capital": "San José",
    "cantidad_de_habitantes": 5150000,
    "PIB": 86500000000,
    "ingreso_per_capita": 14319
}

# %% [markdown]
# ### 🛠️ Imputar valores faltantes para Costa Rica
# Recorremos `datos_cr` y, para cada columna:
#
# 1. **Ubicamos** únicamente las filas de Costa Rica (`mask_cr`).
# 2. **`fillna(valor)`** reemplaza solo los `NaN` con el dato oficial correspondiente.
# 3. Asignamos el resultado de vuelta a la misma columna, dejando intactos los
#    registros de otros países.
#
# De este modo, Costa Rica queda completa sin alterar los valores ya correctos.

# %%
# recorrer datos_cr y para cada columna ubicar las filas Costa Rica mask_cr, fillna(valor) reemplaza solo los NaN
for col, valor in datos_cr.items():
    df_salarios_pais.loc[mask_cr, col] = df_salarios_pais.loc[mask_cr, col].fillna(valor)

# %%
df_salarios_pais.loc[mask_cr]
# Out:
#         nombre   apellido  edad        pais educacion_universitaria  \
# 4       Andrea     Torres    45  Costa Rica                      No
# 13    Fernanda       Ríos    23  Costa Rica                      Sí
# 18       Pedro    Ramírez    54  Costa Rica                      Sí
# 20       Pedro     Torres    22  Costa Rica                      Sí
# 29      Carlos    Herrera    53  Costa Rica                      No
# 31    Fernanda       Díaz    38  Costa Rica                      No
# 32       Diego   González    40  Costa Rica                      No
# 38       Lucía      López    49  Costa Rica                      Sí
# 42       Pedro     Vargas    28  Costa Rica                      No
# 48    Fernanda     Torres    47  Costa Rica                      Sí
# 58      Javier       Díaz    23  Costa Rica                      Sí
# 82      Carlos     Vargas    51  Costa Rica                      No
# 94        Juan   González    56  Costa Rica                      Sí
# 105        Ana      Pérez    42  Costa Rica                      Sí
# 113  Valentina   Martínez    45  Costa Rica                      Sí
# 116      Pedro    Morales    37  Costa Rica                      No
# 131     Andrea      López    38  Costa Rica                      No
# 136   Fernanda  Rodríguez    49  Costa Rica                      Sí
# 140       Luis    Herrera    32  Costa Rica                      Sí
# 141     Carlos     Torres    43  Costa Rica                      No
# 155       José       Díaz    27  Costa Rica                      Sí
# 197        Ana       Ríos    54  Costa Rica                      No
# 205      Pedro      Gómez    40  Costa Rica                      Sí
# 225     Camila  Rodríguez    48  Costa Rica                      Sí
# 226     Javier     Flores    24  Costa Rica                      No
# 227     Camila   Martínez    38  Costa Rica                      Sí
# 228      Lucía      Gómez    32  Costa Rica                      Sí
# 229   Fernanda    Morales    49  Costa Rica                      Sí
# 240     Camila   González    29  Costa Rica                      No
# 244   Fernanda     Vargas    34  Costa Rica                      No
# 254       Juan       Díaz    23  Costa Rica                      No
# 256        Ana     Torres    52  Costa Rica                      Sí
# 258     Carlos      Gómez    42  Costa Rica                      Sí
# 265      Lucía     Torres    36  Costa Rica                      No
# 271      Pedro     Torres    50  Costa Rica                      No
# 281       Juan    Herrera    60  Costa Rica                      No
# 291      Paula       Díaz    53  Costa Rica                      No
# 294       Juan    Morales    49  Costa Rica                      No
# 300      Paula       Díaz    53  Costa Rica                      No
# 303       Juan    Morales    49  Costa Rica                      No
# 309      Lucía     Torres    36  Costa Rica                      No
#
#     nombre_de_la_empresa                      cargo  anos_en_la_empresa  \
# 4          Mercado Libre              Data Engineer                   8
# 13                Oracle              Data Engineer                  10
# 18             Microsoft  Machine Learning Engineer                   2
# 20              Facebook       AI Software Engineer                   6
# 29                 Rappi             Data Scientist                   4
# 31                Oracle            Project Manager                   0
# 32               Globant  Machine Learning Engineer                  12
# 38                  Meta             Data Scientist                  13
# 42              Facebook               Data Analyst                   8
# 48                Google              Product Owner                   7
# 58                Google              Product Owner                   4
# 82                Oracle          Software Engineer                  13
# 94                 Rappi              Product Owner                  10
# 105             Facebook               Data Analyst                   0
# 113        Mercado Libre  Machine Learning Engineer                  13
# 116             Facebook              Data Engineer                   9
# 131               Amazon       AI Software Engineer                  12
# 136               Google            Project Manager                  10
# 140                 Meta       AI Software Engineer                  11
# 141        Mercado Libre  Machine Learning Engineer                   5
# 155                Rappi  Machine Learning Engineer                   2
# 197        Mercado Libre              Product Owner                   6
# 205        Mercado Libre               Data Analyst                  12
# 225                 Meta  Machine Learning Engineer                  12
# 226            Microsoft              Data Engineer                  13
# 227        Mercado Libre          Software Engineer                   4
# 228               Google             Data Scientist                   1
# 229                 Meta            Project Manager                  10
# 240              Globant               Data Analyst                   9
# 244                Rappi             Data Scientist                   7
# 254            Microsoft               Data Analyst                   6
# 256               Google            Project Manager                   5
# 258               Nubank          Software Engineer                  11
# 265               Oracle          Software Engineer                   0
# 271            Microsoft          Software Engineer                   2
# 281                Rappi          Software Engineer                   5
# 291                Rappi  Machine Learning Engineer                  10
# 294               Amazon          Software Engineer                   2
# 300  Empresa Desconocida  Machine Learning Engineer                  10
# 303               Amazon          Software Engineer                   2
# 309  Empresa Desconocida          Software Engineer                   0
#
#      sueldo_anual_dolares  bono_anual_euros  bono_anual_dolares   capital  \
# 4                 84987.0            5493.0              6042.3  San José
# 13                97616.0            8345.0              9179.5  San José
# 18               101737.0            9828.0             10810.8  San José
# 20               115269.0           10657.0             11722.7  San José
# 29                79861.0            7554.0              8309.4  San José
# 31                89704.0            7063.0              7769.3  San José
# 32               104739.0           11879.0             13066.9  San José
# 38                61352.0            7054.0              7759.4  San José
# 42                56598.0            3690.0              4059.0  San José
# 48                87181.0            7291.0              8020.1  San José
# 58                88256.0            8127.0              8939.7  San José
# 82                62222.0            6344.0              6978.4  San José
# 94                84204.0            7141.0              7855.1  San José
# 105               58240.0           13017.0             14318.7  San José
# 113               76052.0           10565.0             11621.5  San José
# 116               69770.0            2575.0              2832.5  San José
# 131               82980.0            5820.0              6402.0  San José
# 136               50469.0            9026.0              9928.6  San José
# 140              153058.0            9289.0             10217.9  San José
# 141               97410.0            9042.0              9946.2  San José
# 155              100670.0           12139.0             13352.9  San José
# 197               60847.0            7323.0              8055.3  San José
# 205               39407.0            7610.0              8371.0  San José
# 225               73296.0            2801.0              3081.1  San José
# 226               91907.0            6232.0              6855.2  San José
# 227              129692.0            8990.0              9889.0  San José
# 228               60620.0           12187.0             13405.7  San José
# 229               56879.0            1962.0              2158.2  San José
# 240               45300.0            6266.0              6892.6  San José
# 244               80431.0            4863.0              5349.3  San José
# 254               59946.0           11829.0             13011.9  San José
# 256               80607.0           13993.0             15392.3  San José
# 258              114949.0            5702.0              6272.2  San José
# 265               86042.0            8746.0              9620.6  San José
# 271               81151.0            9864.0             10850.4  San José
# 281              127936.0            1250.0              1375.0  San José
# 291               70039.0            9874.0             10861.4  San José
# 294              120868.0           12223.0             13445.3  San José
# 300                   NaN            9874.0             10861.4  San José
# 303                   NaN           12223.0             13445.3  San José
# 309               86042.0            8746.0              9620.6  San José
#
#      cantidad_de_habitantes           PIB  ingreso_per_capita  \
# 4                 5150000.0  8.650000e+10             14319.0
# 13                5150000.0  8.650000e+10             14319.0
# 18                5150000.0  8.650000e+10             14319.0
# 20                5150000.0  8.650000e+10             14319.0
# 29                5150000.0  8.650000e+10             14319.0
# 31                5150000.0  8.650000e+10             14319.0
# 32                5150000.0  8.650000e+10             14319.0
# 38                5150000.0  8.650000e+10             14319.0
# 42                5150000.0  8.650000e+10             14319.0
# 48                5150000.0  8.650000e+10             14319.0
# 58                5150000.0  8.650000e+10             14319.0
# 82                5150000.0  8.650000e+10             14319.0
# 94                5150000.0  8.650000e+10             14319.0
# 105               5150000.0  8.650000e+10             14319.0
# 113               5150000.0  8.650000e+10             14319.0
# 116               5150000.0  8.650000e+10             14319.0
# 131               5150000.0  8.650000e+10             14319.0
# 136               5150000.0  8.650000e+10             14319.0
# 140               5150000.0  8.650000e+10             14319.0
# 141               5150000.0  8.650000e+10             14319.0
# 155               5150000.0  8.650000e+10             14319.0
# 197               5150000.0  8.650000e+10             14319.0
# 205               5150000.0  8.650000e+10             14319.0
# 225               5150000.0  8.650000e+10             14319.0
# 226               5150000.0  8.650000e+10             14319.0
# 227               5150000.0  8.650000e+10             14319.0
# 228               5150000.0  8.650000e+10             14319.0
# 229               5150000.0  8.650000e+10             14319.0
# 240               5150000.0  8.650000e+10             14319.0
# 244               5150000.0  8.650000e+10             14319.0
# 254               5150000.0  8.650000e+10             14319.0
# 256               5150000.0  8.650000e+10             14319.0
# 258               5150000.0  8.650000e+10             14319.0
# 265               5150000.0  8.650000e+10             14319.0
# 271               5150000.0  8.650000e+10             14319.0
# 281               5150000.0  8.650000e+10             14319.0
# 291               5150000.0  8.650000e+10             14319.0
# 294               5150000.0  8.650000e+10             14319.0
# 300               5150000.0  8.650000e+10             14319.0
# 303               5150000.0  8.650000e+10             14319.0
# 309               5150000.0  8.650000e+10             14319.0
#
#      compensacion_total senioridad
# 4               91029.3     Senior
# 13             106795.5     Senior
# 18             112547.8     Junior
# 20             126991.7     Senior
# 29              88170.4     Junior
# 31              97473.3     Junior
# 32             117805.9     Senior
# 38              69111.4     Senior
# 42              60657.0     Senior
# 48              95201.1     Senior
# 58              97195.7     Junior
# 82              69200.4     Senior
# 94              92059.1     Senior
# 105             72558.7     Junior
# 113             87673.5     Senior
# 116             72602.5     Senior
# 131             89382.0     Senior
# 136             60397.6     Senior
# 140            163275.9     Senior
# 141            107356.2     Junior
# 155            114022.9     Junior
# 197             68902.3     Senior
# 205             47778.0     Senior
# 225             76377.1     Senior
# 226             98762.2     Senior
# 227            139581.0     Junior
# 228             74025.7     Junior
# 229             59037.2     Senior
# 240             52192.6     Senior
# 244             85780.3     Senior
# 254             72957.9     Senior
# 256             95999.3     Junior
# 258            121221.2     Senior
# 265             95662.6     Junior
# 271             92001.4     Junior
# 281            129311.0     Junior
# 291             80900.4     Senior
# 294            134313.3     Junior
# 300             10861.4     Senior
# 303             13445.3     Junior
# 309             95662.6     Junior

# %% [markdown]
# ### ✅ Verificación final de nulos
# Ejecutamos `df_salarios_pais.isnull().sum()` para confirmar que **todas las
# columnas ahora muestran 0 valores faltantes**. Nuestro DataFrame está listo
# para pasar al Análisis Exploratorio de Datos sin riesgos de errores por `NaN`.

# %%
# verrificar si hay nulos en df_salarios_pais.isnull().sum()
print(df_salarios_pais.isnull().sum())
# Out:
# nombre                     0
# apellido                   0
# edad                       0
# pais                       0
# educacion_universitaria    0
# nombre_de_la_empresa       0
# cargo                      0
# anos_en_la_empresa         0
# sueldo_anual_dolares       7
# bono_anual_euros           0
# bono_anual_dolares         0
# capital                    0
# cantidad_de_habitantes     0
# PIB                        0
# ingreso_per_capita         0
# compensacion_total         0
# senioridad                 0
# dtype: int64

# %%
df_salarios_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nombre                   311 non-null    object
#  1   apellido                 311 non-null    object
#  2   edad                     311 non-null    int64
#  3   pais                     311 non-null    object
#  4   educacion_universitaria  311 non-null    object
#  5   nombre_de_la_empresa     311 non-null    object
#  6   cargo                    311 non-null    object
#  7   anos_en_la_empresa       311 non-null    int64
#  8   sueldo_anual_dolares     304 non-null    float64
#  9   bono_anual_euros         311 non-null    float64
#  10  bono_anual_dolares       311 non-null    float64
#  11  capital                  311 non-null    object
#  12  cantidad_de_habitantes   311 non-null    float64
#  13  PIB                      311 non-null    float64
#  14  ingreso_per_capita       311 non-null    float64
#  15  compensacion_total       311 non-null    float64
#  16  senioridad               311 non-null    object
# dtypes: float64(7), int64(2), object(8)
# memory usage: 41.4+ KB

# %% [markdown]
# ---
# ## 9 · Exportar dataset limpio

# %%
from cursos.analisis_datos.utils.paths import DATA_PROCESSED_DIR

# %%
salarios_pais_path = DATA_PROCESSED_DIR / "salarios_pais.csv"
salarios_pais_path = str(salarios_pais_path)

print(f"Ruta del archivo salarios_paises: {salarios_pais_path}")
print(f"existe archivo salarios_pais: {Path(salarios_pais_path).exists()}")
# Out:
# Ruta del archivo salarios_paises: C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\processed\salarios_pais.csv
# existe archivo salarios_pais: False

# %% [markdown]
# ### 💾 Exportar dataset limpio
# `to_csv(..., index=False, sep=',', encoding='utf-8')` guarda `df_salarios_pais` como un CSV en la ruta definida por `salarios_pais_path`, sin incluir la columna de índice y usando codificación UTF-8.
# La línea `print()` confirma en pantalla la ubicación del archivo generado, facilitando su localización para futuros análisis o compartición.

# %%
# exportar dataset limpio encoding='utf-8' guradar df_salarios_pais como csv, separador ',' path: C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\processed\salarios_pais.csv

df_salarios_pais.to_csv(salarios_pais_path, index=False, encoding='utf-8', sep=',')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[171], line 3
#       1 # exportar dataset limpio encoding='utf-8' guradar df_salarios_pais como csv, separador ',' path: C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\processed\salarios_pais.csv
# ----> 3 df_salarios_pais.to_csv(salarios_pais_path, index=False, encoding='utf-8', sep=',')
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)   3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\Nelson Jr\anaconda3\envs\py-ad-v313\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\processed'

# %%
# 1️⃣ Construir la ruta como objeto Path
salarios_pais_path = Path(
    r"C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\processed\salarios_pais.csv"
)

# 2️⃣ Crear la carpeta (todas las intermedias si no existen)
salarios_pais_path.parent.mkdir(parents=True, exist_ok=True)

# 3️⃣ Exportar el DataFrame
df_salarios_pais.to_csv(salarios_pais_path, index=False, encoding="utf-8", sep=",")

print(f"✅ Archivo guardado en:\n{salarios_pais_path}")
# Out:
# ✅ Archivo guardado en:
# C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\processed\salarios_pais.csv

# %%
print(f' Dataset limpio exportado a {salarios_pais_path}')
# Out:
#  Dataset limpio exportado a C:\Users\Nelson Jr\Documents\Cursos\AnalisisDatos(PythonPanama)\pydatapanama-cursos\cursos\analisis_datos\data\processed\salarios_pais.csv

# %%
print(f"existe archivo salarios_pais: {Path(salarios_pais_path).exists()}")
# Out:
# existe archivo salarios_pais: True

# %% [markdown]
# ---
# ## 10 · Resumen
# En esta práctica aprendiste a:
# - Limpiar columnas con símbolos.
# - Detectar/llenar nulos y eliminar duplicados.
# - Realizar un **merge** y enriquecer tu información.
# - Crear métricas derivadas y exportar datos limpios.
